# %%
import csv
import numpy as np
import matplotlib.pyplot as plt
class ColetorDeSinais:

    Fp1=[]
    Fp2=[]
    F7=[]
    F3=[]
    Fz=[]
    F4=[]
    F8=[]
    FC5=[]
    FC1=[]
    FC2=[]
    FC6=[]
    T7=[]
    C3=[]
    Cz=[]
    C4=[]
    T8=[]
    TP9=[]
    CP5=[]
    CP1=[]
    CP2=[]
    CP6=[]
    TP10=[]
    P7=[]
    P3=[]
    Pz=[]
    P4=[]
    P8=[]
    PO9=[]
    O1=[]
    Oz=[]
    O2=[]
    PO10=[]
    def __init__(self,nPaciente,amostra):
        self.nPaciente=nPaciente
        self.amostra=amostra
        print("Novo paciente -> "+str(nPaciente))
       
    def lerAmostra(self):
                nomeArquivo="subj"+str(self.nPaciente)+"_series"+str(self.amostra)+"_data.csv"
                print(" Lendo a amostra "+str(self.amostra)+" da pessoa numero "+str(self.nPaciente),end="")
                linhas=[]
                with open(nomeArquivo,'r') as arquivo:
                    arquivo_csv=csv.reader(arquivo,delimiter=",")
                    cont=0
                    for (i,linha) in enumerate(arquivo_csv):
                        cont=cont+1
                        if(cont>10000):
                            print(".",end="")
                            cont=0
                        if(i!=0):
                            self.Fp1.append(int(linha[1]))
                            self.Fp2.append(int(linha[2]))
                            self.F7.append(int(linha[3]))
                            self.F3.append(int(linha[4]))
                            self.Fz.append(int(linha[5]))
                            self.F4.append(int(linha[6]))
                            self.F8.append(int(linha[7]))
                            self.FC5.append(int(linha[8]))
                            self.FC1.append(int(linha[9]))
                            self.FC2.append(int(linha[10]))
                            self.FC6.append(int(linha[10]))
                            self.T7.append(int(linha[12]))
                            self.C3.append(int(linha[13]))
                            self.Cz.append(int(linha[14]))
                            self.C4.append(int(linha[15]))
                            self.T8.append(int(linha[16]))
                            self.TP9.append(int(linha[17]))
                            self.CP5.append(int(linha[18]))
                            self.CP1.append(int(linha[19]))
                            self.CP2.append(int(linha[20]))
                            self.CP6.append(int(linha[21]))
                            self.TP10.append(int(linha[22]))
                            self.P7.append(int(linha[23]))
                            self.P3.append(int(linha[24]))
                            self.Pz.append(int(linha[25]))
                            self.P4.append(int(linha[26]))
                            self.P8.append(int(linha[27]))
                            self.PO9.append(int(linha[28]))
                            self.O1.append(int(linha[29]))
                            self.Oz.append(int(linha[30]))
                            self.O2.append(int(linha[31]))
                            self.PO10.append(int(linha[32]))
                    print("leitura finalizada")
    def exibirSinaisEletrodos(self):
        tempo=np.arange(0, len(self.Fp1)/500, 1/500)
        print(" Exibindo sinais dos Eletrodos ", end="")
        plt.figure(figsize=[18,10])
        plt.title("_________________Sinal de EEG da pessoa "+str(self.nPaciente)+", amostra numero " +str(self.amostra)+"_________________")
        plt.xlabel("t(s)")
        plt.ylabel("tensão(uV)")
        plt.plot(tempo,self.Fp1)
        print(".",end="")
        plt.plot(tempo,self.Fp2)
        print(".",end="")
        plt.plot(tempo,self.F7)
        print(".",end="")
        plt.plot(tempo,self.F3)
        print(".",end="")
        plt.plot(tempo,self.Fz)
        print(".",end="")
        plt.plot(tempo,self.F4)
        print(".",end="")
        plt.plot(tempo,self.F8)
        print(".",end="")
        plt.plot(tempo,self.FC5)
        print(".",end="")
        plt.plot(tempo,self.FC1)
        print(".",end="")
        plt.plot(tempo,self.FC2)
        print(".",end="")
        plt.plot(tempo,self.FC6)
        print(".",end="")
        plt.plot(tempo,self.T7)
        print(".",end="")
        plt.plot(tempo,self.C3)
        print(".",end="")
        plt.plot(tempo,self.Cz)
        print(".",end="")
        plt.plot(tempo,self.C4)
        print(".",end="")
        plt.plot(tempo,self.T8)
        print(".",end="")
        plt.plot(tempo,self.TP9)
        print(".",end="")
        plt.plot(tempo,self.CP5)
        print(".",end="")
        plt.plot(tempo,self.CP1)
        print(".",end="")
        plt.plot(tempo,self.CP2)
        print(".",end="")
        plt.plot(tempo,self.CP6)
        print(".",end="")
        plt.plot(tempo,self.TP10)
        print(".",end="")
        plt.plot(tempo,self.P7)
        print(".",end="")
        plt.plot(tempo,self.P3)
        print(".",end="")
        plt.plot(tempo,self.Pz)
        print(".",end="")
        plt.plot(tempo,self.P4)
        print(".",end="")
        plt.plot(tempo,self.P8)
        print(".",end="")
        plt.plot(tempo,self.PO9)
        print(".",end="")
        plt.plot(tempo,self.O1)
        print(".",end="")
        plt.plot(tempo,self.Oz)
        print(".",end="")
        plt.plot(tempo,self.O2)
        print(".",end="")
        plt.show()
        return self.Fp1,self.Fp2,self.F7,self.F3,self.Fz,self.F4,self.F8,self.FC5,self.FC1,self.FC2,self.FC6,self.T7,self.C3,self.Cz,self.C4,self.T8,self.TP9,self.CP5,self.CP1,self.CP2,self.CP6,self.TP10,self.P7,self.P3,self.Pz,self.P4,self.P8,self.PO9,self.O1,self.Oz,self.O2,self.PO10

# %%
print("Digite o numero do Paciente:")

n=int(input());
print("Digite o numero da amostra:")
amostra=int(input())
pacienteNaoEncontrado=(n>12 or n<1)or(amostra>10 or amostra<1)

while(pacienteNaoEncontrado):
    print("Amostra nao encontrada, digite novamente: ")
    n=int(input());
    amostra=int(input())
    pacienteNaoEncontrado=(n>12 or n<1)

sinaisEEG=ColetorDeSinais(n,amostra)
sinaisEEG.lerAmostra()
Fp1,Fp2,F7,F3,Fz,F4,F8,FC5,FC1,FC2,FC6,T7,C3,Cz,C4,T8,TP9,CP5,CP1,CP2,CP6,TP10,P7,P3,Pz,P4,P8,PO9,O1,Oz,O2,PO10=sinaisEEG.exibirSinaisEletrodos()

# %%
import numpy as np
from scipy.fft import fft, ifft

class EstudarSinais():
    def __init__(self,Fp1,Fp2,F7,F3,Fz,F4,F8,FC5,FC1,FC2,FC6,T7,C3,Cz,C4,T8,TP9,CP5,CP1,CP2,CP6,TP10,P7,P3,Pz,P4,P8,PO9,O1,Oz,O2,PO10):
        self.Fp1=np.array(Fp1)
        self.Fp2=np.array(Fp2)
        self.F7=np.array(F7)
        self.F3=np.array(F3)
        self.Fz=np.array(Fz)
        self.F4=np.array(F4)
        self.F8=np.array(F8)
        self.FC5=np.array(FC5)
        self.FC1=np.array(FC1)
        self.FC2=np.array(FC2)
        self.FC6=np.array(FC6)
        self.T7=np.array(T7)
        self.C3=np.array(C3)
        self.Cz=np.array(Cz)
        self.C4=np.array(C4)
        self.T8=np.array(T8)
        self.TP9=np.array(TP9)
        self.CP5=np.array(CP5)
        self.CP1=np.array(CP1)
        self.CP2=np.array(CP2)
        self.CP6=np.array(CP6)
        self.TP10=np.array(TP10)
        self.P7=np.array(P7)
        self.P3=np.array(P3)
        self.Pz=np.array(Pz)
        self.P4=np.array(P4)
        self.P8=np.array(P8)
        self.PO9=np.array(PO9)
        self.O1=np.array(O1)
        self.Oz=np.array(Oz)
        self.O2=np.array(O2)
        self.PO10=np.array(PO10)
        
    def exibirEletrodos(self):
        tempo=np.arange(0, len(self.Fp1)/500, 1/500)
        print("Exibindo eletrodos separadamente",end="")
        plt.figure(figsize=[18,5])
        plt.title("Eletrodo FP1")
        plt.xlabel("t(s)")
        plt.ylabel("tensão(uV)")
        plt.plot(tempo,self.Fp1)
        plt.xlim([0, 1])
        plt.show()
        
        plt.figure(figsize=[18,5])
        plt.title("Eletrodo Fp2")
        plt.xlabel("t(s)")
        plt.ylabel("tensão(uV)")
        plt.plot(tempo,self.Fp2)
        plt.xlim([0, 1])
        plt.show()
        
        plt.figure(figsize=[18,5])
        plt.title("Eletrodo F7")
        plt.xlabel("t(s)")
        plt.ylabel("tensão(uV)")
        plt.plot(tempo,self.F7)
        plt.xlim([0, 1])
        plt.show()
      
        plt.figure(figsize=[18,5])
        plt.title("Eletrodo F3")
        plt.xlabel("t(s)")
        plt.ylabel("tensão(uV)")
        plt.plot(tempo,self.F3)
        plt.xlim([0, 1])
        plt.show()
        
        plt.figure(figsize=[18,5])
        plt.title("Eletrodo Fz")
        plt.xlabel("t(s)")
        plt.ylabel("tensão(uV)")
        plt.plot(tempo,self.Fz)
        plt.xlim([0, 1])
        plt.show()
        
        plt.figure(figsize=[18,5])
        plt.title("Eletrodo F4")
        plt.xlabel("t(s)")
        plt.ylabel("tensão(uV)")
        plt.plot(tempo,self.F4)
        plt.xlim([0, 1])
        plt.show()
        
        plt.figure(figsize=[18,5])
        plt.title("Eletrodo F8")
        plt.xlabel("t(s)")
        plt.ylabel("tensão(uV)")
        plt.plot(tempo,self.F8)
        plt.xlim([0, 1])
        plt.show()
        
        plt.figure(figsize=[18,5])
        plt.title("Eletrodo FC5")
        plt.xlabel("t(s)")
        plt.ylabel("tensão(uV)")
        plt.plot(tempo,self.FC5)
        plt.xlim([0, 1])
        plt.show()
        
        plt.figure(figsize=[18,5])
        plt.title("Eletrodo FC1")
        plt.xlabel("t(s)")
        plt.ylabel("tensão(uV)")
        plt.plot(tempo,self.FC1)
        plt.xlim([0, 1])
        plt.show()
        
        plt.figure(figsize=[18,5])
        plt.title("Eletrodo FC2")
        plt.xlabel("t(s)")
        plt.ylabel("tensão(uV)")
        plt.plot(tempo,self.FC2)
        plt.xlim([0, 1])
        plt.show()
        
        plt.figure(figsize=[18,5])
        plt.title("Eletrodo FC6")
        plt.xlabel("t(s)")
        plt.ylabel("tensão(uV)")
        plt.plot(tempo,self.FC6)
        plt.xlim([0, 1])
        plt.show()
        
        plt.figure(figsize=[18,5])
        plt.title("Eletrodo T7")
        plt.xlabel("t(s)")
        plt.ylabel("tensão(uV)")
        plt.plot(tempo,self.T7)
        plt.xlim([0, 1])
        plt.show()
        
        plt.figure(figsize=[18,5])
        plt.title("Eletrodo C3")
        plt.xlabel("t(s)")
        plt.ylabel("tensão(uV)")
        plt.plot(tempo,self.C3)
        plt.xlim([0, 1])
        plt.show()
        
        plt.figure(figsize=[18,5])
        plt.title("Eletrodo Cz")
        plt.xlabel("t(s)")
        plt.ylabel("tensão(uV)")
        plt.plot(tempo,self.Cz)
        plt.xlim([0, 1])
        plt.show()
        
        plt.figure(figsize=[18,5])
        plt.title("Eletrodo C4")
        plt.xlabel("t(s)")
        plt.ylabel("tensão(uV)")
        plt.plot(tempo,self.C4)
        plt.xlim([0, 1])
        plt.show()
        
        plt.figure(figsize=[18,5])
        plt.title("Eletrodo T8")
        plt.xlabel("t(s)")
        plt.ylabel("tensão(uV)")
        plt.plot(tempo,self.T8)
        plt.xlim([0, 1])
        plt.show()
        
        plt.figure(figsize=[18,5])
        plt.title("Eletrodo TP9")
        plt.xlabel("t(s)")
        plt.ylabel("tensão(uV)")
        plt.plot(tempo,self.TP9)
        plt.xlim([0, 1])
        plt.show()
        
        plt.figure(figsize=[18,5])
        plt.title("Eletrodo v")
        plt.xlabel("t(s)")
        plt.ylabel("tensão(uV)")
        plt.plot(tempo,self.CP5)
        plt.xlim([0, 1])
        plt.show()
        
        plt.figure(figsize=[18,5])
        plt.title("Eletrodo CP1")
        plt.xlabel("t(s)")
        plt.ylabel("tensão(uV)")
        plt.plot(tempo,self.CP1)
        plt.xlim([0, 1])
        plt.show()
        
        plt.figure(figsize=[18,5])
        plt.title("Eletrodo CP2")
        plt.xlabel("t(s)")
        plt.ylabel("tensão(uV)")
        plt.plot(tempo,self.CP2)
        plt.xlim([0, 1])
        plt.show()
        
        plt.figure(figsize=[18,5])
        plt.title("Eletrodo CP6")
        plt.xlabel("t(s)")
        plt.ylabel("tensão(uV)")
        plt.plot(tempo,self.CP6)
        plt.xlim([0, 1])
        plt.show()
        
        plt.figure(figsize=[18,5])
        plt.title("Eletrodo TP10")
        plt.xlabel("t(s)")
        plt.ylabel("tensão(uV)")
        plt.plot(tempo,self.TP10)
        plt.xlim([0, 1])
        plt.show()
        
        plt.figure(figsize=[18,5])
        plt.title("Eletrodo P7")
        plt.xlabel("t(s)")
        plt.ylabel("tensão(uV)")
        plt.plot(tempo,self.P7)
        plt.xlim([0, 1])
        plt.show()
        
        plt.figure(figsize=[18,5])
        plt.title("Eletrodo P3")
        plt.xlabel("t(s)")
        plt.ylabel("tensão(uV)")
        plt.plot(tempo,self.P3)
        plt.xlim([0, 1])
        plt.show()
        
        plt.figure(figsize=[18,5])
        plt.title("Eletrodo Pz")
        plt.xlabel("t(s)")
        plt.ylabel("tensão(uV)")
        plt.plot(tempo,self.Pz)
        plt.xlim([0, 1])
        plt.show()
        
        plt.figure(figsize=[18,5])
        plt.title("Eletrodo P4")
        plt.xlabel("t(s)")
        plt.ylabel("tensão(uV)")
        plt.plot(tempo,self.P4)
        plt.xlim([0, 1])
        plt.show()
        
        plt.figure(figsize=[18,5])
        plt.title("Eletrodo P8")
        plt.xlabel("t(s)")
        plt.ylabel("tensão(uV)")
        plt.plot(tempo,self.P8)
        plt.xlim([0, 1])
        plt.show()
        
        plt.figure(figsize=[18,5])
        plt.title("Eletrodo PO9")
        plt.xlabel("t(s)")
        plt.ylabel("tensão(uV)")
        plt.plot(tempo,self.PO9)
        plt.xlim([0, 1])
        plt.show()
        
        plt.figure(figsize=[18,5])
        plt.title("Eletrodo O1")
        plt.xlabel("t(s)")
        plt.ylabel("tensão(uV)")
        plt.plot(tempo,self.O1)
        plt.xlim([0, 1])
        plt.show()
        
        plt.figure(figsize=[18,5])
        plt.title("Eletrodo Oz")
        plt.xlabel("t(s)")
        plt.ylabel("tensão(uV)")
        plt.plot(tempo,self.Oz)
        plt.xlim([0, 1])
        plt.show()
        

        plt.figure(figsize=[18,5])
        plt.title("Eletrodo O2")
        plt.xlabel("t(s)")
        plt.ylabel("tensão(uV)")
        plt.plot(tempo,self.O2)
        plt.xlim([0, 1])
        plt.show()
        

        plt.figure(figsize=[18,5])
        plt.title("Eletrodo PO10")
        plt.xlabel("t(s)")
        plt.ylabel("tensão(uV)")
        plt.plot(tempo,self.PO10)
        plt.xlim([0, 1])
        plt.show()
        
    def exibirFFT(self):
        freqMaxSinal=30
        intensidadeMaxima=100
        freq_amostragem=500 #hz
        freq=np.linspace(0,freq_amostragem,len(self.Fp1))
        
        fft_Fp1=fft(self.Fp1)/len(self.Fp1)    
        fft_Fp2=fft(self.Fp2)/len(self.Fp2)
        fft_F7=fft(self.F7)/len(self.F7)
        fft_F3=fft(self.F3)/len(self.F3)
        fft_Fz=fft(self.Fz)/len(self.Fz)
        fft_F4=fft(self.Fp1)/len(self.Fp1)
        fft_F8=fft(self.F8)/len(self.F8)
        fft_FC5=fft(self.FC5)/len(self.FC5)
        fft_FC1=fft(self.FC1)/len(self.FC1)
        fft_FC2=fft(self.FC2)/len(self.FC2)
        fft_FC6=fft(self.FC6)/len(self.FC6)
        fft_T7=fft(self.T7)/len(self.T7)
        fft_C3=fft(self.C3)/len(self.C3)
        fft_Cz=fft(self.Cz)/len(self.Cz)
        fft_C4=fft(self.C4)/len(self.C4)
        fft_T8=fft(self.T8)/len(self.T8)
        fft_TP9=fft(self.TP9)/len(self.TP9)
        fft_CP5=fft(self.CP5)/len(self.CP5)
        fft_CP1=fft(self.CP1)/len(self.CP1)
        fft_CP2=fft(self.CP2)/len(self.CP2)
        fft_CP6=fft(self.CP6)/len(self.CP6)
        fft_TP10=fft(self.TP10)/len(self.TP10)
        fft_P7=fft(self.P7)/len(self.P7)
        fft_P3=fft(self.P3)/len(self.P3)
        fft_Pz=fft(self.Pz)/len(self.Pz)
        fft_P4=fft(self.P4)/len(self.P4)
        fft_P8=fft(self.P8)/len(self.P8)
        fft_PO9=fft(self.PO9)/len(self.PO9)
        fft_O1=fft(self.O1)/len(self.O1)
        fft_Oz=fft(self.Oz)/len(self.Oz)
        fft_O2=fft(self.O2)/len(self.O2)
        fft_PO10=fft(self.PO10)/len(self.PO10)
        
        
        plt.figure(figsize=[18,10])
        plt.title("FFT")
        plt.xlabel("Hz")
        plt.ylabel("Intensidade")
        plt.ylim([0, intensidadeMaxima])
        plt.xlim([0, freqMaxSinal])
        plt.plot(freq,np.abs(fft_Fp1))
        
        plt.figure(figsize=[18,10])
        plt.title("FFT")
        plt.xlabel("Hz")
        plt.ylabel("Intensidade")
        plt.xlim([0, freqMaxSinal])
        plt.ylim([0, intensidadeMaxima])
        plt.plot(freq,np.abs(fft_Fp2))
        
        
        plt.figure(figsize=[18,10])
        plt.title("FFT")
        plt.xlabel("Hz")
        plt.ylabel("Intensidade")
        plt.xlim([0, freqMaxSinal])
        plt.ylim([0, intensidadeMaxima])
        plt.plot(freq,np.abs(fft_F7))

        
        plt.figure(figsize=[18,10])
        plt.title("FFT")
        plt.xlabel("Hz")
        plt.ylabel("Intensidade")
        plt.xlim([0, freqMaxSinal])
        plt.ylim([0, intensidadeMaxima])
        plt.plot(freq,np.abs(fft_F3))
        
        plt.figure(figsize=[18,10])
        plt.title("FFT")
        plt.xlabel("Hz")
        plt.ylabel("Intensidade")
        plt.xlim([0, freqMaxSinal])
        plt.ylim([0, intensidadeMaxima])
        plt.plot(freq,np.abs(fft_Fz))
        
        plt.figure(figsize=[18,10])
        plt.title("FFT")
        plt.xlabel("Hz")
        plt.ylabel("Intensidade")
        plt.xlim([0, freqMaxSinal])
        plt.ylim([0, intensidadeMaxima])
        plt.plot(freq,np.abs(fft_F4))
        
        plt.figure(figsize=[18,10])
        plt.title("FFT")
        plt.xlabel("Hz")
        plt.ylabel("Intensidade")
        plt.xlim([0, freqMaxSinal])
        plt.ylim([0, intensidadeMaxima])
        plt.plot(freq,np.abs(fft_F8))
        
        plt.figure(figsize=[18,10])
        plt.title("FFT")
        plt.xlabel("Hz")
        plt.ylabel("Intensidade")
        plt.xlim([0, freqMaxSinal])
        plt.ylim([0, intensidadeMaxima])
        plt.plot(freq,np.abs(fft_FC5))
        
        plt.figure(figsize=[18,10])
        plt.title("FFT")
        plt.xlabel("Hz")
        plt.ylabel("Intensidade")
        plt.xlim([0, freqMaxSinal])
        plt.ylim([0, intensidadeMaxima])
        plt.plot(freq,np.abs(fft_FC1))
        
        plt.figure(figsize=[18,10])
        plt.title("FFT")
        plt.xlabel("Hz")
        plt.ylabel("Intensidade")
        plt.xlim([0, freqMaxSinal])
        plt.ylim([0, intensidadeMaxima])
        plt.plot(freq,np.abs(fft_FC2))
        
        plt.figure(figsize=[18,10])
        plt.title("FFT")
        plt.xlabel("Hz")
        plt.ylabel("Intensidade")
        plt.xlim([0, freqMaxSinal])
        plt.ylim([0, intensidadeMaxima])
        plt.plot(freq,np.abs(fft_FC6))
        
        plt.figure(figsize=[18,10])
        plt.title("FFT")
        plt.xlabel("n")
        plt.ylabel("Intensidade")
        plt.xlim([0, freqMaxSinal])
        plt.ylim([0, intensidadeMaxima])
        plt.plot(freq,np.abs(fft_T7))
        
        plt.figure(figsize=[18,10])
        plt.title("FFT")
        plt.xlabel("Hz")
        plt.ylabel("Intensidade")
        plt.xlim([0, freqMaxSinal])
        plt.ylim([0, intensidadeMaxima])
        plt.plot(freq,np.abs(fft_C3))
        
        plt.figure(figsize=[18,10])
        plt.title("FFT")
        plt.xlabel("Hz")
        plt.ylabel("Intensidade")
        plt.xlim([0, freqMaxSinal])
        plt.ylim([0, intensidadeMaxima])
        plt.plot(freq,np.abs(fft_Cz))
        
        plt.figure(figsize=[18,10])
        plt.title("FFT")
        plt.xlabel("Hz")
        plt.ylabel("Intensidade")
        plt.xlim([0, freqMaxSinal])
        plt.ylim([0, intensidadeMaxima])
        plt.plot(freq,np.abs(fft_C4))
        
        plt.figure(figsize=[18,10])
        plt.title("FFT")
        plt.xlabel("Hz")
        plt.ylabel("Intensidade")
        plt.xlim([0, freqMaxSinal])
        plt.ylim([0, intensidadeMaxima])
        plt.plot(freq,np.abs(fft_T8))
        
        plt.figure(figsize=[18,10])
        plt.title("FFT")
        plt.xlabel("Hz")
        plt.ylabel("Intensidade")
        plt.xlim([0, freqMaxSinal])
        plt.ylim([0, intensidadeMaxima])
        plt.plot(freq,np.abs(fft_TP9))
        
        plt.figure(figsize=[18,10])
        plt.title("FFT")
        plt.xlabel("Hz")
        plt.ylabel("Intensidade")
        plt.xlim([0, freqMaxSinal])
        plt.ylim([0, intensidadeMaxima])
        plt.plot(freq,np.abs(fft_CP5))
        
        plt.figure(figsize=[18,10])
        plt.title("FFT")
        plt.xlabel("Hz")
        plt.ylabel("Intensidade")
        plt.xlim([0, freqMaxSinal])
        plt.ylim([0, intensidadeMaxima])
        plt.plot(freq,np.abs(fft_CP1))
        
        plt.figure(figsize=[18,10])
        plt.title("FFT")
        plt.xlabel("Hz")
        plt.ylabel("Intensidade")
        plt.xlim([0, freqMaxSinal])
        plt.ylim([0, intensidadeMaxima])
        plt.plot(freq,np.abs(fft_CP6))
        
        plt.figure(figsize=[18,10])
        plt.title("FFT")
        plt.xlabel("Hz")
        plt.ylabel("Intensidade")
        plt.xlim([0, freqMaxSinal])
        plt.ylim([0, intensidadeMaxima])
        plt.plot(freq,np.abs(fft_TP10))
        
        plt.figure(figsize=[18,10])
        plt.title("FFT")
        plt.xlabel("Hz")
        plt.ylabel("Intensidade")
        plt.xlim([0, freqMaxSinal])
        plt.ylim([0, intensidadeMaxima])
        plt.plot(freq,np.abs(fft_P7))
        
        plt.figure(figsize=[18,10])
        plt.title("FFT")
        plt.xlabel("Hz")
        plt.ylabel("Intensidade")
        plt.xlim([0, freqMaxSinal])
        plt.ylim([0, intensidadeMaxima])
        plt.plot(freq,np.abs(fft_P3))
        
        plt.figure(figsize=[18,10])
        plt.title("FFT")
        plt.xlabel("Hz")
        plt.ylabel("Intensidade")
        plt.xlim([0, freqMaxSinal])
        plt.ylim([0, intensidadeMaxima])
        plt.plot(freq,np.abs(fft_Pz))
        
        plt.figure(figsize=[18,10])
        plt.title("FFT")
        plt.xlabel("Hz")
        plt.ylabel("Intensidade")
        plt.xlim([0, freqMaxSinal])
        plt.ylim([0, intensidadeMaxima])
        plt.plot(freq,np.abs(fft_P4))
        
        plt.figure(figsize=[18,10])
        plt.title("FFT")
        plt.xlabel("Hz")
        plt.ylabel("Intensidade")
        plt.xlim([0, freqMaxSinal])
        plt.ylim([0, intensidadeMaxima])
        plt.plot(freq,np.abs(fft_P8))
        
        plt.figure(figsize=[18,10])
        plt.title("FFT")
        plt.xlabel("Hz")
        plt.ylabel("Intensidade")
        plt.xlim([0, freqMaxSinal])
        plt.ylim([0, intensidadeMaxima])
        plt.plot(freq,np.abs(fft_PO9))
    
        plt.figure(figsize=[18,10])
        plt.title("FFT")
        plt.xlabel("Hz")
        plt.ylabel("Intensidade")
        plt.xlim([0, freqMaxSinal])
        plt.ylim([0, intensidadeMaxima])
        plt.plot(freq,np.abs(fft_O1))
        
        plt.figure(figsize=[18,10])
        plt.title("FFT")
        plt.xlabel("Hz")
        plt.ylabel("Intensidade")
        plt.xlim([0, freqMaxSinal])
        plt.ylim([0, intensidadeMaxima])
        plt.plot(freq,np.abs(fft_Oz))
        
        plt.figure(figsize=[18,10])
        plt.title("FFT")
        plt.xlabel("Hz")
        plt.ylabel("Intensidade")
        plt.xlim([0, freqMaxSinal])
        plt.ylim([0, intensidadeMaxima])
        plt.plot(freq,np.abs(fft_O2))
        
        plt.figure(figsize=[18,10])
        plt.title("FFT")
        plt.xlabel("Hz")
        plt.ylabel("Intensidade")
        plt.xlim([0, freqMaxSinal])
        plt.ylim([0, intensidadeMaxima])
        plt.plot(freq,np.abs(fft_PO10))
        plt.show()
 
estudarSinais=EstudarSinais(Fp1,Fp2,F7,F3,Fz,F4,F8,FC5,FC1,FC2,FC6,T7,C3,Cz,C4,T8,TP9,CP5,CP1,CP2,CP6,TP10,P7,P3,Pz,P4,P8,PO9,O1,Oz,O2,PO10)

# %%
estudarSinais.exibirEletrodos()

# %%
estudarSinais.exibirFFT()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# "Lobo frontal: relacionado com trabalho criativo, raciocínio, personalidade, tomada de decisões, movimentação dos músculos esqueléticos, entre outras funções.

# Lobo temporal: atua, principalmente, na comunicação, relacionando-se com a audição e compreensão da linguagem.

# Lobo parietal: relacionado, entre outras funções, com a percepção de dor, frio, calor e toques.

# Lobo occipital: possui relação com o processamento das informações visuais."

# Veja mais sobre "Cérebro" em: https://brasilescola.uol.com.br/biologia/cerebro-humano.htm



class Cerebro:
    def __init__(self,Fp1,Fp2,F7,F3,Fz,F4,F8,FC5,FC1,FC2,FC6,T7,C3,Cz,C4,T8,TP9,CP5,CP1,CP2,CP6,TP10,P7,P3,Pz,P4,P8,PO9,O1,Oz,O2,PO10):
        self.Fp1=np.array(Fp1)
        self.Fp2=np.array(Fp2)
        self.F7=np.array(F7)
        self.F3=np.array(F3)
        self.Fz=np.array(Fz)
        self.F4=np.array(F4)
        self.F8=np.array(F8)
        self.FC5=np.array(FC5)
        self.FC1=np.array(FC1)
        self.FC2=np.array(FC2)
        self.FC6=np.array(FC6)
        self.T7=np.array(T7)
        self.C3=np.array(C3)
        self.Cz=np.array(Cz)
        self.C4=np.array(C4)
        self.T8=np.array(T8)
        self.TP9=np.array(TP9)
        self.CP5=np.array(CP5)
        self.CP1=np.array(CP1)
        self.CP2=np.array(CP2)
        self.CP6=np.array(CP6)
        self.TP10=np.array(TP10)
        self.P7=np.array(P7)
        self.P3=np.array(P3)
        self.Pz=np.array(Pz)
        self.P4=np.array(P4)
        self.P8=np.array(P8)
        self.PO9=np.array(PO9)
        self.O1=np.array(O1)
        self.Oz=np.array(Oz)
        self.O2=np.array(O2)
        self.PO10=np.array(PO10)

    
    def obterLobos(self):
                
        self.LoboFrontalE=(self.Fp1+self.F7+self.F3)/3
        self.LoboFrontalD=(self.Fp2+self.F4+self.F8)/3
        
        self.LoboParietalE=(self.CP5+self.CP1+self.P3)/3
        self.LoboParietalD=(self.CP2+self.CP6+self.P4)/3
        
        self.LoboTemporalE=(self.T7+self.TP9)/2
        self.LoboTemporalD=(self.T8+self.TP10)/2
        
        self.LoboOccipitalE=O1
        self.LoboOccipitalD=O2

        
        return self.LoboFrontalE,self.LoboFrontalD, self.LoboParietalE,self.LoboParietalD,self.LoboTemporalE,self.LoboTemporalD,self.LoboOccipitalE,self.LoboOccipitalD

# %%
cerebro = Cerebro(Fp1,Fp2,F7,F3,Fz,F4,F8,FC5,FC1,FC2,FC6,T7,C3,Cz,C4,T8,TP9,CP5,CP1,CP2,CP6,TP10,P7,P3,Pz,P4,P8,PO9,O1,Oz,O2,PO10)

LFE,LFD,LPE,LPD,LTE,LTD,LOE,LOD=cerebro.obterLobos()

# %%
### SEU CÓDIGO COMEÇA AQUI ###

import numpy as np, scipy as sp, matplotlib.pyplot as plt, time
from scipy import signal
# %matplotlib inline

print("Projeto de filtro para obter a onda Delta")

#especificação do tipo de filtro

wp1=0.1*np.pi*2
wp2=4*np.pi*2

wr1=0*np.pi*2
wr2=5*np.pi*2


wpf=[wp1, wp2]  #frequencia de atenuaçãp
wrf=[wr1, wr2]  #frequencia de passagem


           #parametros do filtro
Ap=5  #atenuação Máxima na banda de passagem   
Ar=20 #atenuação mínima na banda de atenuação


Nf,Wnf   = signal.ellipord(wpf, wrf, Ap, Ar,analog=True)#filtro bp

print("Filtro eliptico de ordem ",Nf)

b,a= signal.ellip(Nf,Ap,Ar, Wnf, 'bp', True,'ba')
#b,a= signal.butter(Nf, Wnf, 'bp', True,'ba')
filtroDelta=signal.lti(b,a)



w,bp= signal.freqresp(filtroDelta)

plt.figure(figsize=(10,4))

plt.plot(w,20*np.log10(np.abs(bp)))
plt.xlim(wr1*0.9,wr2*1.1)
plt.fill([0,  wrf[0],  wrf[0], 0], [-Ar, -Ar,-0, 0], '0.9', lw=0)
plt.fill([wpf[0],  wpf[1],  wpf[1], wpf[0]], [-100, -100,-Ap, -Ap], '0.9', lw=0)
plt.fill([wrf[1],  100**3,  100**3,   wrf[1]], [-Ar, -Ar, 0, 0], '0.9', lw=0)
plt.title("Filtro passa faixa de ondas Delta com fc="+str(wpf[0]/(2*np.pi))+" Hz e "+str(wpf[1]//(2*np.pi))+" Hz")
plt.xlabel("rad/s")
plt.ylabel("Db")
plt.show()
############################Fim do filtro de Onda delta

# %%
print("Projeto de filtro para obter a onda Teta")

#especificação do tipo de filtro

wp1=4*np.pi*2
wp2=8*np.pi*2

wr1=3*np.pi*2
wr2=9*np.pi*2


wpf=[wp1, wp2]  #frequencia de atenuaçãp
wrf=[wr1, wr2]  #frequencia de passagem


           #parametros do filtro
Ap=5  #atenuação Máxima na banda de passagem   
Ar=30 #atenuação mínima na banda de atenuação


Nf,Wnf   = signal.ellipord(wpf, wrf, Ap, Ar,analog=True)#filtro bp

print("Filtro eliptico de ordem ",Nf)

b,a= signal.ellip(Nf,Ap,Ar, Wnf, 'bp', True,'ba')
#b,a= signal.butter(Nf, Wnf, 'bp', True,'ba')
filtroTeta=signal.lti(b,a)



w,bp= signal.freqresp(filtroTeta)

plt.figure(figsize=(10,4))

plt.plot(w,20*np.log10(np.abs(bp)))
plt.xlim(wr1*0.9,wr2*1.1)
plt.fill([0,  wrf[0],  wrf[0], 0], [-Ar, -Ar,-0, 0], '0.9', lw=0)
plt.fill([wpf[0],  wpf[1],  wpf[1], wpf[0]], [-100, -100,-Ap, -Ap], '0.9', lw=0)
plt.fill([wrf[1],  100**3,  100**3,   wrf[1]], [-Ar, -Ar, 0, 0], '0.9', lw=0)
plt.title("Filtro passa faixa de ondas Teta com fc="+str(wpf[0]/(2*np.pi))+" Hz e "+str(wpf[1]//(2*np.pi))+" Hz")
plt.xlabel("rad/s")
plt.ylabel("Db")
plt.show()

# %%
print("Projeto de filtro para obter a onda Alfa")

#especificação do tipo de filtro

wp1=8*np.pi*2
wp2=13*np.pi*2

wr1=7.9*np.pi*2
wr2=13.1*np.pi*2


wpf=[wp1, wp2]  #frequencia de atenuaçãp
wrf=[wr1, wr2]  #frequencia de passagem


           #parametros do filtro
Ap=5  #atenuação Máxima na banda de passagem   
Ar=30 #atenuação mínima na banda de atenuação


Nf,Wnf   = signal.ellipord(wpf, wrf, Ap, Ar,analog=True)#filtro bp

print("Filtro eliptico de ordem ",Nf)

b,a= signal.ellip(Nf,Ap,Ar, Wnf, 'bp', True,'ba')
#b,a= signal.butter(Nf, Wnf, 'bp', True,'ba')
filtroAlfa=signal.lti(b,a)



w,bp= signal.freqresp(filtroAlfa)

plt.figure(figsize=(10,4))

plt.plot(w,20*np.log10(np.abs(bp)))
plt.xlim(wr1*0.9,wr2*1.1)
plt.fill([0,  wrf[0],  wrf[0], 0], [-Ar, -Ar,-0, 0], '0.9', lw=0)
plt.fill([wpf[0],  wpf[1],  wpf[1], wpf[0]], [-100, -100,-Ap, -Ap], '0.9', lw=0)
plt.fill([wrf[1],  100**3,  100**3,   wrf[1]], [-Ar, -Ar, 0, 0], '0.9', lw=0)
plt.title("Filtro passa faixa de ondas Alfa com fc="+str(wpf[0]/(2*np.pi))+" Hz e "+str(wpf[1]//(2*np.pi))+" Hz")
plt.xlabel("rad/s")
plt.ylabel("Db")
plt.show()

# %%
print("Projeto de filtro para obter a onda Beta")

#especificação do tipo de filtro

wp1=13*np.pi*2
wp2=30*np.pi*2

wr1=12.8*np.pi*2
wr2=31*np.pi*2


wpf=[wp1, wp2]  #frequencia de atenuaçãp
wrf=[wr1, wr2]  #frequencia de passagem


           #parametros do filtro
Ap=5  #atenuação Máxima na banda de passagem   
Ar=30 #atenuação mínima na banda de atenuação


Nf,Wnf   = signal.ellipord(wpf, wrf, Ap, Ar,analog=True)#filtro bp

print("Filtro eliptico de ordem ",Nf)

b,a= signal.ellip(Nf,Ap,Ar, Wnf, 'bp', True,'ba')
#b,a= signal.butter(Nf, Wnf, 'bp', True,'ba')
filtroBeta=signal.lti(b,a)



w,bp= signal.freqresp(filtroBeta)

plt.figure(figsize=(10,4))

plt.plot(w,20*np.log10(np.abs(bp)))
plt.xlim(wr1*0.9,wr2*1.1)
plt.fill([0,  wrf[0],  wrf[0], 0], [-Ar, -Ar,-0, 0], '0.9', lw=0)
plt.fill([wpf[0],  wpf[1],  wpf[1], wpf[0]], [-100, -100,-Ap, -Ap], '0.9', lw=0)
plt.fill([wrf[1],  100**3,  100**3,   wrf[1]], [-Ar, -Ar, 0, 0], '0.9', lw=0)
plt.title("Filtro passa faixa de ondas Beta com fc="+str(wpf[0]/(2*np.pi))+" Hz e "+str(wpf[1]//(2*np.pi))+" Hz")
plt.xlabel("rad/s")
plt.ylabel("Db")
plt.show()

# %%
LFE,LFD,LPE,LPD,LTE,LTD,LOE,LOD
tempo=np.arange(0, len(LFE)/500, 1/500)
print("___________________________________Atividade cerebral antes do filtro__________________________")
plt.figure(figsize=[18,5])
plt.title("Lobo frontal")
plt.xlabel("t(s)")
plt.ylabel("tensão(uV)")
plt.plot(tempo,LFE,label="Lobo Frontal Esquerdo",alpha=0.4)
plt.plot(tempo,LFD,label="Lobo Frontal direito",alpha=0.4)
plt.xlim([0, 1])
plt.legend()

plt.figure(figsize=[18,5])
plt.title("Lobo Pariental")
plt.xlabel("t(s)")
plt.ylabel("tensão(uV)")
plt.plot(tempo,LPE,label="Lobo Pariental Esquerdo",alpha=0.4)
plt.plot(tempo,LPD,label="Lobo Pariental direito",alpha=0.4)
plt.xlim([0, 1])
plt.legend()

plt.figure(figsize=[18,5])
plt.title("Lobo Temporal")
plt.xlabel("t(s)")
plt.ylabel("tensão(uV)")
plt.plot(tempo,LTE,label="Lobo Temporal Esquerdo",alpha=0.4)
plt.plot(tempo,LTD,label="Lobo Temporal direito",alpha=0.4)
plt.xlim([0, 1])
plt.legend()

plt.figure(figsize=[18,5])
plt.title("Lobo Occipital")
plt.xlabel("t(s)")
plt.ylabel("tensão(uV)")
plt.plot(tempo,LOE,label="Lobo Occipital Esquerdo",alpha=0.4)
plt.plot(tempo,LOD,label="Lobo Occipital direito",alpha=0.4)
plt.xlim([0, 1])
plt.legend()

# %%
class FiltraCerebro:
    def __init__(self,filtroDelta,filtroTeta,filtroAlfa,filtroBeta,N,T):
        self.filtroDelta=filtroDelta
        self.filtroTeta=filtroTeta
        self.filtroAlfa=filtroAlfa
        self.filtroBeta=filtroBeta
        self.tempo=np.arange(0, T*N, T)
        
    def filtrar(self,lobo,tipoDeFiltro):
        print(".",end="")
        tout, y, x=signal.lsim(filtroDelta,lobo, self.tempo)
        
        if(tipoDeFiltro=="teta"):
            tout, y, x=signal.lsim(filtroTeta,lobo, self.tempo)
        if(tipoDeFiltro=="alfa"):
            tout, y, x=signal.lsim(filtroAlfa,lobo, self.tempo)
        if(tipoDeFiltro=="beta"):
            tout, y, x=signal.lsim(filtroBeta,lobo, self.tempo)
            
        return y   
        
    def obterOndas(self,lobo):
        return self.filtrar(lobo,"delta"),self.filtrar(lobo,"teta"),self.filtrar(lobo,"alfa"),self.filtrar(lobo,"beta")

# %%
print("Filtrando cerebro",end="[...")
N=len(LFE)

print("10%",end="...")
filtraCerebro=FiltraCerebro(filtroDelta,filtroTeta,filtroAlfa,filtroBeta,N,1/500)
print("20%",end="...")

deltaLFE,tetaLFE,alfaLFE,betaLFE=filtraCerebro.obterOndas(LFE)
print("30%",end="...")
deltaLFD,tetaLFD,alfaLFD,betaLFD=filtraCerebro.obterOndas(LFD)
print("40%",end="...")
deltaLPE,tetaLPE,alfaLPE,betaLPE=filtraCerebro.obterOndas(LPE)
print("50%",end="...")
deltaLPD,tetaLPD,alfaLPD,betaLPD=filtraCerebro.obterOndas(LPD)
print("60%",end="...")
deltaLTE,tetaLTE,alfaLTE,betaLTE=filtraCerebro.obterOndas(LTE)
print("70%",end="...")
deltaLTD,tetaLTD,alfaLTD,betaLTD=filtraCerebro.obterOndas(LTD)
print("80%",end="...")
deltaLOE,tetaLOE,alfaLOE,betaLOE=filtraCerebro.obterOndas(LOE)
print("90%",end="...")
deltaLOD,tetaLOD,alfaLOD,betaLOD=filtraCerebro.obterOndas(LOD)
print("100%",end="...]\n ->Filtro concluido\n")

# %%
print("___________________________________Atividade cerebral Depos do filtro__________________________")
tempo=np.arange(0, len(deltaLFE)/500, 1/500)
plt.figure(figsize=[18,5])
plt.title("Lobo frontal esquerdo")
plt.xlabel("t(s)")
plt.ylabel("tensão(uV)")
plt.plot(tempo,deltaLFE,label="delta",alpha=0.4)
plt.plot(tempo,alfaLFE,label="teta",alpha=0.4)
plt.plot(tempo,betaLFE,label="alfa",alpha=0.4)
plt.plot(tempo,tetaLFE,label="beta",alpha=0.4)
plt.xlim([0, 1])
plt.legend()

plt.figure(figsize=[18,5])
plt.title("Lobo frontal direito")
plt.xlabel("t(s)")
plt.ylabel("tensão(uV)")
plt.plot(tempo,deltaLFD,label="delta",alpha=0.4)
plt.plot(tempo,alfaLFD,label="teta",alpha=0.4)
plt.plot(tempo,betaLFD,label="alfa",alpha=0.4)
plt.plot(tempo,tetaLFD,label="beta",alpha=0.4)
plt.xlim([0, 1])
plt.legend()

plt.figure(figsize=[18,5])
plt.title("Lobo Pariental Esquerdo")
plt.xlabel("t(s)")
plt.ylabel("tensão(uV)")
plt.plot(tempo,deltaLPE,label="delta",alpha=0.4)
plt.plot(tempo,alfaLPE,label="teta",alpha=0.4)
plt.plot(tempo,betaLPE,label="alfa",alpha=0.4)
plt.plot(tempo,tetaLPE,label="beta",alpha=0.4)
plt.xlim([0, 1])
plt.legend()

plt.figure(figsize=[18,5])
plt.title("Lobo Pariental Direito")
plt.xlabel("t(s)")
plt.ylabel("tensão(uV)")
plt.plot(tempo,deltaLPD,label="delta",alpha=0.4)
plt.plot(tempo,alfaLPD,label="teta",alpha=0.4)
plt.plot(tempo,betaLPD,label="alfa",alpha=0.4)
plt.plot(tempo,tetaLPD,label="beta",alpha=0.4)
plt.xlim([0, 1])
plt.legend()

plt.figure(figsize=[18,5])
plt.title("Lobo Temporal Esquerdo")
plt.xlabel("t(s)")
plt.ylabel("tensão(uV)")
plt.plot(tempo,deltaLTE,label="delta",alpha=0.4)
plt.plot(tempo,alfaLTE,label="teta",alpha=0.4)
plt.plot(tempo,betaLTE,label="alfa",alpha=0.4)
plt.plot(tempo,tetaLTE,label="beta",alpha=0.4)
plt.xlim([0, 1])
plt.legend()

plt.figure(figsize=[18,5])
plt.title("Lobo Temporal Direito")
plt.xlabel("t(s)")
plt.ylabel("tensão(uV)")
plt.plot(tempo,deltaLTD,label="delta",alpha=0.4)
plt.plot(tempo,alfaLTD,label="teta",alpha=0.4)
plt.plot(tempo,betaLTD,label="alfa",alpha=0.4)
plt.plot(tempo,tetaLTD,label="beta",alpha=0.4)
plt.xlim([0, 1])
plt.legend()

plt.figure(figsize=[18,5])
plt.title("Lobo Occipital Esquerdo")
plt.xlabel("t(s)")
plt.ylabel("tensão(uV)")
plt.plot(tempo,deltaLOE,label="delta",alpha=0.4)
plt.plot(tempo,alfaLOE,label="teta",alpha=0.4)
plt.plot(tempo,betaLOE,label="alfa",alpha=0.4)
plt.plot(tempo,tetaLOE,label="beta",alpha=0.4)
plt.xlim([0, 1])
plt.legend()

plt.figure(figsize=[18,5])
plt.title("Lobo Occipital Direito")
plt.xlabel("t(s)")
plt.ylabel("tensão(uV)")
plt.plot(tempo,deltaLOD,label="delta",alpha=0.4)
plt.plot(tempo,alfaLOD,label="teta",alpha=0.4)
plt.plot(tempo,betaLOD,label="alfa",alpha=0.4)
plt.plot(tempo,tetaLOD,label="beta",alpha=0.4)
plt.xlim([0, 1])
plt.legend()

# %%
class Relatorio:
    def __init__(self,delta,teta,alfa,beta):
        self.delta=delta
        self.teta=teta
        self.alfa=alfa
        self.beta=beta
    def calcularEnergia(self):

               
        T=1/500
        t=T*len(self.delta)
        energiaDelta=np.sum(np.abs(self.delta**2))/(T)
        energiaTeta=np.sum(np.abs(self.teta**2))/(T)
        energiaAlfa=np.sum(np.abs(self.alfa**2))/(T)
        energiaBeta=np.sum(np.abs(self.beta**2))/(T)
        
        return energiaDelta, energiaTeta, energiaAlfa, energiaBeta           
    def plotarFFT(self,title):
        D,T,A,B=self.calcularEnergia()
        energiaTotal=D+T+A+B
        
        pesoTotal=200+100+50+30
        
        eD=D/energiaTotal
        eT=T/energiaTotal
        eA=A/energiaTotal
        eB=B/energiaTotal
        freq=np.linspace(0,500,len(self.delta))
        deltaFFT=fft(self.delta)/len(self.delta)
        alfaFFT=fft(self.alfa)/len(self.alfa)
        betaFFT=fft(self.beta)/len(self.beta)
        tetaFFT=fft(self.teta)/len(self.teta)
        plt.figure(figsize=[18,5])
        plt.title("Atividade Cerebra-> " +title)
        plt.xlabel("Hz")
        plt.ylabel("Intensidade")
        plt.plot(freq,np.abs(deltaFFT),label="Energia delta -> "+str(100*eD//1)+"%",alpha=0.4)
        plt.plot(freq,np.abs(alfaFFT),label="Energia alfaa -> "+str(100*eA//1)+"%",alpha=0.4)
        plt.plot(freq,np.abs(betaFFT),label="Energia beta -> "+str(100*eB//1)+"%",alpha=0.4)
        plt.plot(freq,np.abs(tetaFFT),label="Energia teta -> "+str(100*eT//1)+"%",alpha=0.4)
        plt.xlim([0, 35])
        plt.legend()
        
    def plotarFFTNormalizada(self,title):
        D,T,A,B=self.calcularEnergia()
        energiaTotal=D+T+A+B
        
        pesoTotal=200+100+50+30
        
        eD=D/energiaTotal
        eT=T/energiaTotal
        eA=A/energiaTotal
        eB=B/energiaTotal
        freq=np.linspace(0,500,len(self.delta))
        deltaFFT=fft(self.delta)/len(self.delta)
        alfaFFT=fft(self.alfa)/len(self.alfa)
        betaFFT=fft(self.beta)/len(self.beta)
        tetaFFT=fft(self.teta)/len(self.teta)
        plt.figure(figsize=[18,5])
        plt.title("Atividade Cerebra-> " +title)
        plt.xlabel("Hz")
        plt.ylabel("Intensidade")
        plt.plot(freq,np.abs(deltaFFT)/200,label="Energia delta -> "+str(100*eD//1)+"%(Amplificado 1 vez)",alpha=0.4)
        plt.plot(freq,np.abs(alfaFFT)/100,label="Energia alfaa -> "+str(100*eA//1)+"%(Amplificado 2 vezes)",alpha=0.4)
        plt.plot(freq,np.abs(betaFFT)/50,label="Energia beta -> "+str(100*eB//1)+"%(Amplificado 4 vezes)",alpha=0.4)
        plt.plot(freq,np.abs(tetaFFT)/30,label="Energia teta -> "+str(100*eT//1)+"%(Amplificado 6 vezes)",alpha=0.4)
        plt.xlim([0, 35])
        plt.legend()        
        
        
    def plotarFase(self,title):
        D,T,A,B=self.calcularEnergia()
        energiaTotal=D+T+A+B
        
        pesoTotal=200+100+50+30
        
        eD=D/energiaTotal
        eT=T/energiaTotal
        eA=A/energiaTotal
        eB=B/energiaTotal
        freq=np.linspace(0,500,len(self.delta))
        deltaFFT=fft(self.delta)/len(self.delta)
        alfaFFT=fft(self.alfa)/len(self.alfa)
        betaFFT=fft(self.beta)/len(self.beta)
        tetaFFT=fft(self.teta)/len(self.teta)
        plt.figure(figsize=[18,5])
        plt.title("Atividade Cerebra-> " +title)
        plt.xlabel("Hz")
        plt.ylabel("Intensidade")
        plt.plot(freq,np.angle(deltaFFT),label="Energia delta -> "+str(100*eD//1)+"%",alpha=0.4)
        plt.plot(freq,np.angle(alfaFFT),label="Energia alfa -> "+str(100*eA//1)+"%",alpha=0.4)
        plt.plot(freq,np.angle(betaFFT),label="Energia beta -> "+str(100*eB//1)+"%",alpha=0.4)
        plt.plot(freq,np.angle(tetaFFT),label="Energia teta -> "+str(100*eT//1)+"%",alpha=0.4)
        plt.xlim([0, 30])
        plt.legend()
        

relatorioLFE= Relatorio(deltaLFE,tetaLFE,alfaLFE,betaLFE)
relatorioLPE= Relatorio(deltaLPE,tetaLPE,alfaLPE,betaLPE)
relatorioLTE= Relatorio(deltaLTE,tetaLTE,alfaLTE,betaLTE)
relatorioLOE= Relatorio(deltaLOE,tetaLOE,alfaLOE,betaLOE)

relatorioLFD= Relatorio(deltaLFD,tetaLFD,alfaLFD,betaLFD)
relatorioLPD= Relatorio(deltaLPD,tetaLPD,alfaLPD,betaLPD)
relatorioLTD= Relatorio(deltaLTD,tetaLTD,alfaLTD,betaLTD)
relatorioLOD= Relatorio(deltaLOD,tetaLOD,alfaLOD,betaLOD)

# %%
print("___________________________________Atividade cerebral depois do filtro no dominio da frequencia__________________________")

relatorioLFE.plotarFFT("Lobo Frontal Esquerdo")
relatorioLPE.plotarFFT("Lobo Parietal Esquerdo")
relatorioLTE.plotarFFT("Lobo Temporal Esquerdo")
relatorioLOE.plotarFFT("Lobo Occipital Esquerdo")

relatorioLFD.plotarFFT("Lobo Frontal direito")
relatorioLPD.plotarFFT("Lobo Parietal direito")
relatorioLTD.plotarFFT("Lobo Temporal direito")
relatorioLOD.plotarFFT("Lobo Occipital direito")

# %%
print("___________________________________Atividade cerebral depois do filtro no dominio da frequencia Normalizado__________________________")

relatorioLFE.plotarFFTNormalizada("Lobo Frontal Esquerdo")
relatorioLPE.plotarFFTNormalizada("Lobo Parietal Esquerdo")
relatorioLTE.plotarFFTNormalizada("Lobo Temporal Esquerdo")
relatorioLOE.plotarFFTNormalizada("Lobo Occipital Esquerdo")

relatorioLFD.plotarFFTNormalizada("Lobo Frontal direito")
relatorioLPD.plotarFFTNormalizada("Lobo Parietal direito")
relatorioLTD.plotarFFTNormalizada("Lobo Temporal direito")
relatorioLOD.plotarFFTNormalizada("Lobo Occipital direito")

# %%
print("___________________________________Atividade cerebral depois do filtro no dominio da frequencia__________________________")

relatorioLFE.plotarFase("Lobo Frontal Esquerdo")
relatorioLPE.plotarFase("Lobo Parietal Esquerdo")
relatorioLTE.plotarFase("Lobo Temporal Esquerdo")
relatorioLOE.plotarFase("Lobo Occipital Esquerdo")

relatorioLFD.plotarFase("Lobo Frontal direito")
relatorioLPD.plotarFase("Lobo Parietal direito")
relatorioLTD.plotarFase("Lobo Temporal direito")
relatorioLOD.plotarFase("Lobo Occipital direito")
